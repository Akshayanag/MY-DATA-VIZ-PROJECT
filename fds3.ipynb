# %%
import pandas as pd
df=pd.read_csv("IPL IMB381IPL2013.csv")
(df)
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.tail(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
print(list(df.columns))
# Out:
# ['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE', 'SOLD PRICE']

# %%
df.shape
# Out:
# (130, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df.loc[0:9]
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.loc[0:10]
# Out:
#     Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0        1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1        2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2        3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3        4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4        5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5        6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6        7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7        8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8        9       Botha, J    2      SA    RR   Allrounder      83      17
# 9       10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
# 10      11      Bravo, DJ    2      WI   MI+   Allrounder    2200      86
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %% [markdown]
# df.loc[1]

# %%
df.loc[1]
# Out:
# Sl.NO.                      2
# PLAYER NAME      Abdur Razzak
# AGE                         2
# COUNTRY                   BAN
# TEAM                      RCB
# PLAYING ROLE           Bowler
# T-RUNS                    214
# T-WKTS                     18
# ODI-RUNS-S                657
# ODI-SR-B                71.41
# ODI-WKTS                  185
# ODI-SR-BL                37.6
# CAPTAINCY EXP               0
# RUNS-S                      0
# HS                          0
# AVE                       0.0
# SR-B                      0.0
# SIXERS                      0
# RUNS-C                     29
# WKTS                        0
# AVE-BL                    0.0
# ECON                     14.5
# SR-BL                     0.0
# AUCTION YEAR             2008
# BASE PRICE              50000
# SOLD PRICE              50000
# Name: 1, dtype: object

# %%
df.loc[2]
# Out:
# Sl.NO.                     3
# PLAYER NAME      Agarkar, AB
# AGE                        2
# COUNTRY                  IND
# TEAM                     KKR
# PLAYING ROLE          Bowler
# T-RUNS                   571
# T-WKTS                    58
# ODI-RUNS-S              1269
# ODI-SR-B               80.62
# ODI-WKTS                 288
# ODI-SR-BL               32.9
# CAPTAINCY EXP              0
# RUNS-S                   167
# HS                        39
# AVE                    18.56
# SR-B                  121.01
# SIXERS                     5
# RUNS-C                  1059
# WKTS                      29
# AVE-BL                 36.52
# ECON                    8.81
# SR-BL                   24.9
# AUCTION YEAR            2008
# BASE PRICE            200000
# SOLD PRICE            350000
# Name: 2, dtype: object

# %%
df[["PLAYER NAME","COUNTRY"]]
# Out:
#       PLAYER NAME COUNTRY
# 0     Abdulla, YA      SA
# 1    Abdur Razzak     BAN
# 2     Agarkar, AB     IND
# 3       Ashwin, R     IND
# 4    Badrinath, S     IND
# ..            ...     ...
# 125     Yadav, AS     IND
# 126   Younis Khan     PAK
# 127  Yuvraj Singh     IND
# 128   Zaheer Khan     IND
# 129    Zoysa, DNT      SL
#
# [130 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=130, step=1)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.iloc[4:1,1:4]
# Out:
# Empty DataFrame
# Columns: [PLAYER NAME, AGE, COUNTRY]
# Index: []

# %%
s_age=df.groupby('AGE')['SOLD PRICE'].mean()
s_age
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
df["AGE"]
# Out:
# 0      2
# 1      2
# 2      2
# 3      1
# 4      2
#       ..
# 125    2
# 126    2
# 127    2
# 128    2
# 129    2
# Name: AGE, Length: 130, dtype: int64

# %%
print(df.groupby('AGE'))

# %%
s_age=df.groupby('AGE')['SOLD PRICE'].mean().reset_index()

# %%
s_age=df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
s_age
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df['PREMIUM']=df['SOLD PRICE']-df['BASE PRICE']

# %%
df['PREMIUM']=df['SOLD PRICE']-df['BASE PRICE']
df['PREMIUM']
# Out:
# 0            0
# 1            0
# 2       150000
# 3       750000
# 4       700000
#         ...
# 125     700000
# 126          0
# 127    1400000
# 128     250000
# 129      10000
# Name: PREMIUM, Length: 130, dtype: int64
